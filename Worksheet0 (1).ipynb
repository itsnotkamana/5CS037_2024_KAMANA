# %%
#Task 1. Classify Temperatures:
temperatures = [8.2, 17.4, 14.1, 7.9, 18.0, 13.5, 9.0, 17.8, 13.0, 8.5,
16.5, 12.9, 7.7, 17.2, 13.3, 8.4, 16.7, 14.0, 9.5, 18.3, 13.4, 8.1,
17.9, 14.2, 7.6, 17.0, 12.8, 8.0, 16.8, 13.7, 7.8, 17.5, 13.6, 8.7,
17.1, 13.8, 9.2, 18.1, 13.9, 8.3, 16.4, 12.7, 8.9, 18.2, 13.1, 7.8,
16.6, 12.5]

Cold=[]
Mild=[]
Comfortable=[]

for i in temperatures:
    if i<10:
        Cold.append(i)
    elif i<15:
        Mild.append(i)
    elif i<20:
        Comfortable.append(i)
        
print("Cold:",Cold)
print("Mild:",Mild)
print("Comfortable:",Comfortable)
# Out:
# Cold: [8.2, 7.9, 9.0, 8.5, 7.7, 8.4, 9.5, 8.1, 7.6, 8.0, 7.8, 8.7, 9.2, 8.3, 8.9, 7.8]
# Mild: [14.1, 13.5, 13.0, 12.9, 13.3, 14.0, 13.4, 14.2, 12.8, 13.7, 13.6, 13.8, 13.9, 12.7, 13.1, 12.5]
# Comfortable: [17.4, 18.0, 17.8, 16.5, 17.2, 16.7, 18.3, 17.9, 17.0, 16.8, 17.5, 17.1, 18.1, 16.4, 18.2, 16.6]

# %%
#Task 2. Based on Data
cold_count=0
mild_count=0
comfortable_count=0

for i in Cold:
    cold_count+=1
for i in Mild:
    mild_count+=1
for i in Comfortable:
    comfortable_count+=1
print(cold_count)
print(mild_count)
print(comfortable_count)
# Out:
# 16
# 16
# 16

# %%
#Task 3. Convert Temperatures from Celsius to Fahrenheit
temperatures_fahrenheit=[]
for i in temperatures:
    fahrenheit=(i*(9/5)+32)
    temperatures_fahrenheit.append(fahrenheit)
print("Converted Temperatures from Celsius to Fahrenheit: ",temperatures_fahrenheit)
# Out:
# Converted Temperatures from Celsius to Fahrenheit:  [46.76, 63.31999999999999, 57.379999999999995, 46.22, 64.4, 56.3, 48.2, 64.03999999999999, 55.400000000000006, 47.3, 61.7, 55.22, 45.86, 62.96, 55.94, 47.120000000000005, 62.06, 57.2, 49.1, 64.94, 56.120000000000005, 46.58, 64.22, 57.56, 45.68, 62.6, 55.040000000000006, 46.4, 62.24, 56.66, 46.04, 63.5, 56.480000000000004, 47.66, 62.78, 56.84, 48.56, 64.58000000000001, 57.019999999999996, 46.94, 61.519999999999996, 54.86, 48.019999999999996, 64.75999999999999, 55.58, 46.04, 61.88, 54.5]

# %%
#Task 4. Analyze Temperature Patterns by Time of Day:

import matplotlib.pyplot as plt

temperatures = [
    8.2, 17.4, 14.1, 7.9, 18.0, 13.5, 9.0, 17.8, 13.0, 8.5,
    16.5, 12.9, 7.7, 17.2, 13.3, 8.4, 16.7, 14.0, 9.5, 18.3, 
    13.4, 8.1, 17.9, 14.2, 7.6, 17.0, 12.8, 8.0, 16.8, 13.7, 
    7.8, 17.5, 13.6, 8.7, 17.1, 13.8, 9.2, 18.1, 13.9, 8.3, 
    16.4, 12.7, 8.9, 18.2, 13.1, 7.8, 16.6, 12.5
]

night_temps = []
day_temps = []
evening_temps = []

for i, temp in enumerate(temperatures):
    if i % 24 < 8:  
        night_temps.append(temp)
    elif i % 24 < 16:  
        evening_temps.append(temp)
    else: 
        day_temps.append(temp)

avg_day_temp = sum(day_temps) / len(day_temps)
print(f"Average day-time temperature: {avg_day_temp:.2f}°C")

days = list(range(1, len(day_temps) + 1))
plt.plot(days, day_temps, marker='o', label="Daytime Temperatures", color='orange')
plt.xlabel("Day")
plt.ylabel("Temperature (°C)")
plt.title("Day vs. Temperature")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Average day-time temperature: 13.64°C

# %%
#8.1.1 Exercise - Recursion:Task 1 - Sum of Nested Lists:
def sum_nested_list(nested_list):
    
    total = 0  

    for element in nested_list:
        if isinstance(element, list):  
            total += sum_nested_list(element)
        else:
            total += element
    return total  

nested_list = [1, [2, [3, 4], 5], 6, [7, 8]]
result = sum_nested_list(nested_list)
print(f"The total sum of {nested_list} is: {result}")

nested_list2 = [1, [2, 3], [4, [5]]]
result2 = sum_nested_list(nested_list2)
print(f"The total sum of {nested_list2} is: {result2}")
# Out:
# The total sum of [1, [2, [3, 4], 5], 6, [7, 8]] is: 36
# The total sum of [1, [2, 3], [4, [5]]] is: 15

# %%
#Task 2 - Generate All Permutations of a String:

def generate_permutations(s):
    if len(s) <= 1:
        return [s]
    permutations = []
    for i in range(len(s)):

        char = s[i]

        remaining = s[:i] + s[i+1:]

        for perm in generate_permutations(remaining):
            permutations.append(char + perm)
            
    return sorted(list(set(permutations))) 
    
print(generate_permutations("abc"))

print(generate_permutations("aab"))
# Out:
# ['abc', 'acb', 'bac', 'bca', 'cab', 'cba']
# ['aab', 'aba', 'baa']

# %%
#Task 3 - Directory Size Calculation:
def calculate_directory_size(directory):
    total_size = 0

    for item, value in directory.items():
        if isinstance(value, dict):
            total_size += calculate_directory_size(value)
        else:
            # If it's not a dictionary, it's a file, so add its size to the total
            total_size += value

    return total_size  # Return the total size

directory_structure = {
    "file1.txt": 200,
    "file2.txt": 300,
    "subdir1": {
        "file3.txt": 400,
        "file4.txt": 100
    },
    "subdir2": {
        "subsubdir1": {
            "file5.txt": 250
        },
        "file6.txt": 150
    }
}

print(calculate_directory_size(directory_structure))
# Out:
# 1400

# %%
#Task 1 - Coin Change Problem:
def min_coins(coins, amount):

    # Initialize the DP table with a large value (infinity)
    dp = [float('inf')] * (amount + 1)
    dp[0] = 0  # Base case: 0 coins are needed for amount 0

    # Fill the DP table
    for coin in coins:
        for i in range(coin, amount + 1):
            dp[i] = min(dp[i], dp[i - coin] + 1)

    return dp[amount] if dp[amount] != float('inf') else -1

# Test case
coins = [1, 2, 5]
amount = 11
print(min_coins(coins, amount))  # Output: 3
# Out:
# 3

# %%
#Task 2 - Longest Common Subsequence (LCS):
def longest_common_subsequence(s1, s2):
    
    n, m = len(s1), len(s2)
    dp = [[0] * (m + 1) for _ in range(n + 1)]

    # Fill the DP table
    for i in range(1, n + 1):
        for j in range(1, m + 1):
            if s1[i - 1] == s2[j - 1]:
                dp[i][j] = dp[i - 1][j - 1] + 1
            else:
                dp[i][j] = max(dp[i - 1][j], dp[i][j - 1])

    return dp[n][m]

# Test case
s1 = "abcde"
s2 = "ace"
print(longest_common_subsequence(s1, s2))
# Out:
# 3

# %%
#Task 3 - 0/1 Knapsack Problem:
def knapsack(weights, values, capacity):
    
    n = len(weights)
    dp = [[0] * (capacity + 1) for _ in range(n + 1)]

    # Fill the DP table
    for i in range(1, n + 1):
        for w in range(1, capacity + 1):
            if weights[i - 1] <= w:
                dp[i][w] = max(dp[i - 1][w], dp[i - 1][w - weights[i - 1]] + values[i - 1])
            else:
                dp[i][w] = dp[i - 1][w]

    return dp[n][capacity]

# Test case
weights = [1, 3, 4, 5]
values = [1, 4, 5, 7]
capacity = 7
print(knapsack(weights, values, capacity))
# Out:
# 9

# %%
import numpy as np
A = np.array([[1 , 2] , [3 , 4]])
B = np. =array([5 , 6])
print (" Inverse:\n", np.linalg.inv( A ) )
print (" Determinant :", np.linalg.det( A ) )
print (" Frobenius Norm :", np.linalg.norm(A , 'fro') )
print ("2 - Norm ( Euclidean ):", np.linalg.norm(A))
print (" Solution x:", np.linalg.solve(A , B ))
# Out:
#   Cell In[6], line 3
#     B = np. =array([5 , 6])
#             ^
# SyntaxError: invalid syntax

# %%
import numpy as np #Imports the NumPy library and assigns it the alias np
A = np.array([[1, 2], [3, 4]]) #creates a 2D array (a 2*2 matrix)
B = np.array([5, 6]) #creates a 1D array (vector)
print("Inverse:\n", np.linalg.inv(A))
print("Determinant:", np.linalg.det(A))# indicates whether a matrix is invertible
print("Frobenius Norm:", np.linalg.norm(A, 'fro'))#measures the size of the matrix by summing the squares of all elements:
print("2-Norm (Euclidean):", np.linalg.norm(A))#measures the largest singular value of the matrix
print("Solution x:", np.linalg.solve(A, B))
# Out:
# Inverse:
#  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Determinant: -2.0000000000000004
# Frobenius Norm: 5.477225575051661
# 2-Norm (Euclidean): 5.477225575051661
# Solution x: [-4.   4.5]
